# %% [markdown]
# # Cleaning Workzone Data from 2018-2024
# #### Import Libraries

# %%
import pandas as pd
import numpy as np
import os
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import geopandas as gpd

# %% [markdown]
# #### Read data and clean it

# %%
data = pd.read_excel("CMU RCRS Data - 2017-18/Events Report 2018 - 2020.xlsx")

# Preliminarily how many work zones per year in the raw file?
data['BEGINNING_DATE'] = pd.to_datetime(data['BEGINNING_DATE'])
data['Year'] = data['BEGINNING_DATE'].dt.year
data.groupby('Year').size()
# Out:
# Year
# 2018    69320
# 2019    74850
# 2020    64483
# dtype: int64

# %%
wdata=data.copy()
wdata.head()
# Out:
#    EVENTID     DISTRICT                                        STATE_ROUTE  \
# 0   357901  District 08  2018  (CHOCOLATE AV / WALTON AV / BRIDGE RD / ...
# 1   357920  District 08                                   0114  (PA - 114)
# 2   359196  District 08                            4001  (OLD CARLISLE RD)
# 3   360002  District 08  3047  (IRON RIDGE RD / MAPLE GROVE RD / KRAFTS...
# 4   361537  District 06                                    0095  (I - 095)
#
#   DIRECTION                                      FROM_LOCATION  \
# 0      BOTH      HUMMELSTOWN  [BORO]_!_ROSANNA ST DAUPHIN (22)
# 1      BOTH  0262  (PA - 262) - FISHING CREEK RD in FAIRVIE...
# 2      BOTH            BUTLER  [2TWP]_!_GUERNSEY RD ADAMS (01)
# 3      BOTH  0516  (PA - 516) - BERLIN STREET in JEFFERSON ...
# 4     SOUTH  GIRARD AVE/LEHIGH AVE  { # 23 } PHILADELPHIA (67)
#
#                                         END_LOCATION INCIDENT_LOCATION  \
# 0      HUMMELSTOWN  [BORO]_!_HANOVER ST DAUPHIN (22)
# 1           FAIRVIEW  [2TWP]_!_RUDYTOWN RD YORK (66)
# 2        BUTLER  [2TWP]_!_CENTER MILLS RD ADAMS (01)
# 3          NORTH CODORUS  [2TWP]_!_PARK RD YORK (66)
# 4  ALLEGHENY AVE/CASTER AVE  { # 25 } PHILADELPHI...
#
#                    INFO_PROVIDED_BY                                VERIFIED  \
# 0                     DEAN MARRIOTT               01/26/2018 18:06:00 OTHER
# 1                      RUDY HUGGINS   01/09/2018 08:45:00 PENNDOT PERSONNEL
# 2  RODNEY GIBSON / CLEARWATER CONST  01/02/2018 08:20:00 PRIVATE CONTRACTOR
# 3                     CLINT LEAKWAY   01/09/2018 09:01:00 PENNDOT PERSONNEL
# 4                   CARLTON MCVEIGH                12/31/2017 23:59:00 CCTV
#
#               CAUSE  ... IS_DETOUR_IN_PLACE IS_DETOUR_EFFECTIVE  \
# 0     SPECIAL EVENT  ...                  T                   T
# 1          ROADWORK  ...                  T                   T
# 2     BRIDGE OUTAGE  ...                  F                 NaN
# 3          ROADWORK  ...                  F                 NaN
# 4  DISABLED VEHICLE  ...                  F                 NaN
#
#   DETOUR_DESCRIPTION FIRST_RESPONDERS_ARRIVE PENNDOT_ARRIVE DURATION_IN_HOURS  \
# 0                NaN                     NaN            NaN          4.776667
# 1                NaN                     NaN            NaN        557.599722
# 2                NaN                     NaN            NaN       5354.028056
# 3                NaN                     NaN            NaN        748.562222
# 4                NaN                     NaN            NaN          0.492778
#
#                BEGIN_LOCATION_LATLONG                END_LOCATION_LATLONG  \
# 0  40.2652210679873,-76.7098815896065   40.2653242756258,-76.707868762623
# 1  40.1815337221234,-76.8788784102723  40.1884307467765,-76.8893313120578
# 2    39.953891008477,-77.211833076343  39.9553087688289,-77.2112441196716
# 3  39.8210804126407,-76.8451685782727  39.8180782732112,-76.8726839582193
# 4   39.983192889809,-75.0986559582808  39.9781083768692,-75.1113919811173
#
#   INCIDENT_LOCATION_LATLONG  Year
# 0                       NaN  2018
# 1                       NaN  2018
# 2                       NaN  2018
# 3                       NaN  2018
# 4                       NaN  2018
#
# [5 rows x 42 columns]

# %%
wdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 208653 entries, 0 to 208652
# Data columns (total 42 columns):
#  #   Column                                            Non-Null Count   Dtype
# ---  ------                                            --------------   -----
#  0   EVENTID                                           208653 non-null  int64
#  1   DISTRICT                                          208653 non-null  object
#  2   STATE_ROUTE                                       208653 non-null  object
#  3   DIRECTION                                         208653 non-null  object
#  4   FROM_LOCATION                                     208653 non-null  object
#  5   END_LOCATION                                      208653 non-null  object
#  6   INCIDENT_LOCATION                                 208653 non-null  object
#  7   INFO_PROVIDED_BY                                  208653 non-null  object
#  8   VERIFIED                                          208653 non-null  object
#  9   CAUSE                                             208653 non-null  object
#  10  STATUS                                            208653 non-null  object
#  11  CLOSURE_INFORMATION                               76263 non-null   object
#  12  BEGINNING_DATE                                    208653 non-null  datetime64[ns]
#  13  EST_DATE_TO_OPEN                                  208653 non-null  object
#  14  ACT_DATETIME_OPENED                               208626 non-null  object
#  15  RECORD_EDITED                                     208653 non-null  object
#  16  IS_AIRCRAFT                                       208653 non-null  object
#  17  IS_AMISH_CONVEYANCE                               208653 non-null  object
#  18  IS_AUTONOMOUS_VEHICLE                             208653 non-null  object
#  19  IS_BRIDGE_STRIKE                                  208653 non-null  object
#  20  IS_COMMERCIAL_VEHICLE_ROLLOVER                    208653 non-null  object
#  21  IS_CRASH_IN_CONSTRUCTION_ZONE                     208653 non-null  object
#  22  IS_FIRST_RESPONDER_WITH_MAJOR_INJURY_OR_FATALITY  208653 non-null  object
#  23  IS_PENNDOT_PROPERTY_OR_EMPLOYEE_INVOLVED          208653 non-null  object
#  24  IS_TEMP_TRAFFIC_CONTROL_DEVICE                    208653 non-null  object
#  25  IS_TRAIN                                          208653 non-null  object
#  26  IS_TRANSIT_TOUR_BUS                               208653 non-null  object
#  27  FATALITY                                          208653 non-null  object
#  28  SCHOOL_BUS                                        208653 non-null  object
#  29  HAZMAT                                            208653 non-null  object
#  30  CONTACT                                           208653 non-null  object
#  31  DESCRIPTION_OF_EVENT                              195667 non-null  object
#  32  IS_DETOUR_IN_PLACE                                208204 non-null  object
#  33  IS_DETOUR_EFFECTIVE                               2575 non-null    object
#  34  DETOUR_DESCRIPTION                                0 non-null       float64
#  35  FIRST_RESPONDERS_ARRIVE                           14960 non-null   object
#  36  PENNDOT_ARRIVE                                    6286 non-null    object
#  37  DURATION_IN_HOURS                                 208626 non-null  float64
#  38  BEGIN_LOCATION_LATLONG                            149181 non-null  object
#  39  END_LOCATION_LATLONG                              149166 non-null  object
#  40  INCIDENT_LOCATION_LATLONG                         64714 non-null   object
#  41  Year                                              208653 non-null  int32
# dtypes: datetime64[ns](1), float64(2), int32(1), int64(1), object(37)
# memory usage: 66.1+ MB

# %%
# Drop unnecessary columns
wdata.drop(columns=['CLOSURE_INFORMATION', 'IS_DETOUR_EFFECTIVE', 'DETOUR_DESCRIPTION', 'FIRST_RESPONDERS_ARRIVE', 'PENNDOT_ARRIVE'], inplace=True)

# %%
# Filter based on clean data
wdata = wdata[(wdata['END_LOCATION_LATLONG'].notnull()) & (wdata['BEGIN_LOCATION_LATLONG'].notnull()) & \
    (wdata['END_LOCATION_LATLONG'] != ",") & (wdata['BEGIN_LOCATION_LATLONG'] != ",")]
wdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 149087 entries, 0 to 208652
# Data columns (total 37 columns):
#  #   Column                                            Non-Null Count   Dtype
# ---  ------                                            --------------   -----
#  0   EVENTID                                           149087 non-null  int64
#  1   DISTRICT                                          149087 non-null  object
#  2   STATE_ROUTE                                       149087 non-null  object
#  3   DIRECTION                                         149087 non-null  object
#  4   FROM_LOCATION                                     149087 non-null  object
#  5   END_LOCATION                                      149087 non-null  object
#  6   INCIDENT_LOCATION                                 149087 non-null  object
#  7   INFO_PROVIDED_BY                                  149087 non-null  object
#  8   VERIFIED                                          149087 non-null  object
#  9   CAUSE                                             149087 non-null  object
#  10  STATUS                                            149087 non-null  object
#  11  BEGINNING_DATE                                    149087 non-null  datetime64[ns]
#  12  EST_DATE_TO_OPEN                                  149087 non-null  object
#  13  ACT_DATETIME_OPENED                               149063 non-null  object
#  14  RECORD_EDITED                                     149087 non-null  object
#  15  IS_AIRCRAFT                                       149087 non-null  object
#  16  IS_AMISH_CONVEYANCE                               149087 non-null  object
#  17  IS_AUTONOMOUS_VEHICLE                             149087 non-null  object
#  18  IS_BRIDGE_STRIKE                                  149087 non-null  object
#  19  IS_COMMERCIAL_VEHICLE_ROLLOVER                    149087 non-null  object
#  20  IS_CRASH_IN_CONSTRUCTION_ZONE                     149087 non-null  object
#  21  IS_FIRST_RESPONDER_WITH_MAJOR_INJURY_OR_FATALITY  149087 non-null  object
#  22  IS_PENNDOT_PROPERTY_OR_EMPLOYEE_INVOLVED          149087 non-null  object
#  23  IS_TEMP_TRAFFIC_CONTROL_DEVICE                    149087 non-null  object
#  24  IS_TRAIN                                          149087 non-null  object
#  25  IS_TRANSIT_TOUR_BUS                               149087 non-null  object
#  26  FATALITY                                          149087 non-null  object
#  27  SCHOOL_BUS                                        149087 non-null  object
#  28  HAZMAT                                            149087 non-null  object
#  29  CONTACT                                           149087 non-null  object
#  30  DESCRIPTION_OF_EVENT                              140289 non-null  object
#  31  IS_DETOUR_IN_PLACE                                148658 non-null  object
#  32  DURATION_IN_HOURS                                 149063 non-null  float64
#  33  BEGIN_LOCATION_LATLONG                            149087 non-null  object
#  34  END_LOCATION_LATLONG                              149087 non-null  object
#  35  INCIDENT_LOCATION_LATLONG                         5309 non-null    object
#  36  Year                                              149087 non-null  int32
# dtypes: datetime64[ns](1), float64(1), int32(1), int64(1), object(33)
# memory usage: 42.7+ MB

# %%
# Convert to date time
wdata['ACT_DATETIME_OPENED'] = pd.to_datetime(wdata['ACT_DATETIME_OPENED'])
wdata['Year'] = wdata['ACT_DATETIME_OPENED'].dt.year

# %%
# Filter by cause the duration
wdata = wdata[wdata['CAUSE'] == 'ROADWORK']
wdata = wdata[(wdata['DURATION_IN_HOURS'] <= (7*24)) & (wdata['DURATION_IN_HOURS'] > 0)]

# %%
# How many are left per year?
data.groupby('Year').size()
# Out:
# Year
# 2018    69320
# 2019    74850
# 2020    64483
# dtype: int64

# %%
wdata = wdata[['EVENTID', 'DIRECTION', 'STATE_ROUTE', 'BEGIN_LOCATION_LATLONG', 'END_LOCATION_LATLONG', 'BEGINNING_DATE', \
    'ACT_DATETIME_OPENED', 'DURATION_IN_HOURS']]

# %%
# Clean st rt no and direction columns
wdata['ST_RT_NO'] = (wdata['STATE_ROUTE'].str[:4]).astype(int)
wdata.drop(columns=['STATE_ROUTE'], inplace=True)
wdata['DIRECTION'] = wdata['DIRECTION'].str[0]
wdata.head()
# Out:
#     EVENTID DIRECTION              BEGIN_LOCATION_LATLONG  \
# 83   361616         E  39.9528201289115,-76.7484358158499
# 88   361621         B   40.697267282843,-80.3890556951048
# 92   361625         B  40.0471409885973,-75.7160158119286
# 95   361628         S   40.153599046815,-77.3023022732082
# 96   361629         B  39.8376674032663,-75.6973863879682
#
#                   END_LOCATION_LATLONG      BEGINNING_DATE  \
# 83  39.9514275303733,-76.7476956127466 2018-01-02 07:17:50
# 88   40.6942457919881,-80.373508844171 2018-01-02 08:16:00
# 92   40.035105842437,-75.7093626228477 2018-01-02 08:33:01
# 95  40.1293449089626,-77.3493401405175 2018-01-02 08:59:10
# 96  39.8401605943598,-75.7100399702765 2018-01-02 09:07:04
#
#    ACT_DATETIME_OPENED  DURATION_IN_HOURS  ST_RT_NO
# 83 2018-01-02 15:55:00           8.619444      3054
# 88 2018-01-02 17:16:00           9.000000      4028
# 92 2018-01-02 08:34:00           0.016389       282
# 95 2018-01-02 14:50:00           5.847222        81
# 96 2018-01-02 15:48:00           6.682222        82

# %%
# Write to file
wdata.to_csv("cleaned_2018-2020_workzones.csv")

# %%
# Again for the 2021-2024 file
data2 = pd.read_excel("CMU RCRS Data - 2017-18/Events Report 2021 - 2024.xlsx")
wdata2 = data2.copy()
wdata2.head()
# Out:
#    EVENTID     DISTRICT                             STATE_ROUTE DIRECTION  \
# 0   570322  District 08                     2080  (GRACETON RD)      BOTH
# 1   571023  District 08  4022  (LEWISBERRY RD / SIDDONSBURG RD)      BOTH
# 2   571083  District 09                         0099  (I - 099)     NORTH
# 3   571084  District 09                         0099  (I - 099)     SOUTH
# 4   571085  District 09                         0099  (I - 099)     NORTH
#
#                                        FROM_LOCATION  \
# 0  FAWN  [2TWP]_!_BRYANSVILLE RD, CONSTITUTION RD...
# 1              FAIRVIEW  [2TWP]_!_MARIE AV YORK (66)
# 2                (Beginning of I - 099) BEDFORD (05)
# 3                      (End of I - 099) BEDFORD (05)
# 4                (Beginning of I - 099) BEDFORD (05)
#
#                                 END_LOCATION INCIDENT_LOCATION  \
# 0  PEACH BOTTOM  [2TWP]_!_GROSS RD YORK (66)
# 1       FAIRVIEW  [2TWP]_!_WEST ST YORK (66)
# 2               (End of I - 099) CENTRE (14)
# 3         (Beginning of I - 099) CENTRE (14)
# 4               (End of I - 099) CENTRE (14)
#
#    INFO_PROVIDED_BY                               VERIFIED           CAUSE  \
# 0         ADAM HOFF  01/06/2021 07:46:00 PENNDOT PERSONNEL        ROADWORK
# 1  KEITH DRIESBAUGH  01/14/2021 07:31:00 PENNDOT PERSONNEL        ROADWORK
# 2      AREA COMMAND                   01/01/2021 09:58:00   WINTER WEATHER
# 3      AREA COMMAND                   01/01/2021 09:59:00   WINTER WEATHER
# 4      AREA COMMAND                   01/01/2021 10:03:00   WINTER WEATHER
#
#    ...                               DESCRIPTION_OF_EVENT IS_DETOUR_IN_PLACE  \
# 0  ...  Planned Event Description History:\n\t01/06/20...                  F
# 1  ...                                     Extend to 2/26                  F
# 2  ...                                                NaN                  F
# 3  ...                                                NaN                  F
# 4  ...                                                NaN                  F
#
#   IS_DETOUR_EFFECTIVE DETOUR_DESCRIPTION FIRST_RESPONDERS_ARRIVE  \
# 0                 NaN                NaN                     NaN
# 1                 NaN                NaN                     NaN
# 2                   F                NaN                     NaN
# 3                   F                NaN                     NaN
# 4                   F                NaN                     NaN
#
#   PENNDOT_ARRIVE DURATION_IN_HOURS              BEGIN_LOCATION_LATLONG  \
# 0            NaN          6.612222  39.7212324915759,-76.4148035083266
# 1            NaN        987.797222  40.1391058074007,-76.8712487050507
# 2            NaN          9.165000  40.0558545550851,-78.5179413563517
# 3            NaN          9.160556  40.9421749880512,-77.7256600364977
# 4            NaN          9.024722  40.0558545550851,-78.5179413563517
#
#                  END_LOCATION_LATLONG INCIDENT_LOCATION_LATLONG
# 0  39.7212224130221,-76.3964464770387                       NaN
# 1  40.1371588034077,-76.8668174250536                       NaN
# 2  40.9421749880512,-77.7256600364977                       NaN
# 3  40.0558574483092,-78.5182656870055                       NaN
# 4  40.9421749880512,-77.7256600364977                       NaN
#
# [5 rows x 41 columns]

# %%
data2['BEGINNING_DATE'] = pd.to_datetime(data2['BEGINNING_DATE'])
data2['Year'] = data2['BEGINNING_DATE'].dt.year
data2.groupby('Year').size()
# Out:
# Year
# 2021    71228
# 2022    72167
# 2023    77931
# 2024    35919
# dtype: int64

# %%
wdata2['BEGINNING_DATE'] = pd.to_datetime(wdata2['BEGINNING_DATE'])
wdata2['Year'] = wdata2['BEGINNING_DATE'].dt.year
wdata2.groupby('Year').size()
# Out:
# Year
# 2021    71228
# 2022    72167
# 2023    77931
# 2024    35919
# dtype: int64

# %%
wdata2 = wdata2[(wdata2['END_LOCATION_LATLONG'].notnull()) & (wdata2['BEGIN_LOCATION_LATLONG'].notnull()) & \
    (wdata2['END_LOCATION_LATLONG'] != ",") & (wdata2['BEGIN_LOCATION_LATLONG'] != ",")]
wdata2 = wdata2[wdata2['CAUSE'] == 'ROADWORK']
wdata2 = wdata2[(wdata2['DURATION_IN_HOURS'] <= (7*24)) & (wdata2['DURATION_IN_HOURS'] > 0)]
wdata2.groupby('Year').size()
# Out:
# Year
# 2021    21294
# 2022    21712
# 2023    24863
# 2024     9976
# dtype: int64

# %%
wdata2['ST_RT_NO'] = (wdata2['STATE_ROUTE'].str[:4]).astype(int)

wdata2 = wdata2[['EVENTID', 'DIRECTION', 'ST_RT_NO', 'BEGIN_LOCATION_LATLONG', 'END_LOCATION_LATLONG', 'BEGINNING_DATE', 'ACT_DATETIME_OPENED', 'DURATION_IN_HOURS']]
wdata2['DIRECTION'] = wdata2['DIRECTION'].str[0]
wdata2.head()
# Out:
#      EVENTID DIRECTION  ST_RT_NO              BEGIN_LOCATION_LATLONG  \
# 0     570322         B      2080  39.7212324915759,-76.4148035083266
# 151   571293         W       376  40.4319959343462,-79.9594417422336
# 164   571306         N       476  40.0664399416518,-75.3210564972281
# 311   571453         W      3002  40.3108069600006,-75.1287759369276
# 333   571476         S       119  40.2431835180538,-79.5766592049683
#
#                    END_LOCATION_LATLONG      BEGINNING_DATE  \
# 0    39.7212224130221,-76.3964464770387 2021-01-06 07:46:16
# 151  40.4345714299781,-79.9653194030498 2021-01-02 08:32:03
# 164  40.0953717941557,-75.3033130917345 2021-01-02 12:28:36
# 311  40.3099915397151,-75.1304857375297 2021-01-03 21:51:54
# 333  40.2402651996861,-79.5787191971731 2021-01-04 06:11:19
#
#      ACT_DATETIME_OPENED  DURATION_IN_HOURS
# 0    01/06/2021 14:23:00           6.612222
# 151  01/02/2021 11:51:00           3.315833
# 164  01/02/2021 13:54:00           1.423333
# 311  01/04/2021 05:03:00           7.185000
# 333  01/08/2021 16:48:00         106.611389

# %%
wdata2.to_csv('cleaned_2021-2024_workzones.csv')
